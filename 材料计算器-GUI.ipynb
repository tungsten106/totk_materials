# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd


def calculate_materials():
    selected_equipment = equipment_data[
        (equipment_data['名称'] == combo_equipment.get()) & (equipment_data['升级等级'] == (combo_level.get()))]

    selected_materials = pd.DataFrame(columns=['材料名称', '需要的数量'])

    selected_materials = pd.DataFrame(columns=['材料名称', '需要的数量'])
    for _, row in selected_equipment.iterrows():
        material = row['材料名称']
        quantity = row['需要的数量']
        selected_materials = selected_materials.append({'材料名称': material, '需要的数量': quantity},
                                                           ignore_index=True)
#     selected_materials
    
    total_materials = selected_materials.groupby('材料名称')['需要的数量'].sum().reset_index()

    result_text.delete(1.0, tk.END)
    result_text.insert(tk.END, total_materials.to_string(index=False))


equipment_data = pd.read_csv('Documents/material_output.csv')

# 创建主窗口
window = tk.Tk()
window.title("装备材料计算器")

# 创建下拉选择框和标签
label_equipment = ttk.Label(window, text="装备名称:")
label_equipment.pack()
combo_equipment = ttk.Combobox(window, values=equipment_data['名称'].unique().tolist())
combo_equipment.pack()

label_level = ttk.Label(window, text="装备等级:")
label_level.pack()
combo_level = ttk.Combobox(window, values=equipment_data['升级等级'].unique().tolist())
combo_level.pack()

# 创建计算按钮
calculate_button = ttk.Button(window, text="计算", command=calculate_materials)
calculate_button.pack()

# 创建结果文本框
result_text = tk.Text(window, height=10, width=30)
result_text.pack()

# 启动主循环
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 52
#      49 result_text.pack()
#      51 # 启动主循环
# ---> 52 window.mainloop()
#
# File ~/anaconda3/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
equipment_data = pd.read_csv('Documents/material_output.csv')
equipment_data['名称'].unique()
# Out:
# array(['古代勇者之魂', '神兽兵装·梅德', '神兽兵装·露塔', '神兽兵装·鲁达尼亚', '神兽兵装·娜波力斯', '鬼神帽子',
#        '鬼神服', '鬼神靴', '黄昏之勇者套装', '风之勇者套装', '时光之勇者套装', '初始之勇者套装', '天空之勇者套装',
#        '织梦套装', '旷野之勇者帽子', '旷野之勇者服', '旷野之勇者裤子', '依盖队套装', '近卫兵套装', '蛮族套装',
#        '卓拉套装', '耐火套装', '羽绒套装', '橡胶套装'], dtype=object)

# %%
equipment_data
# Out:
#      Unnamed: 0      名称 套装效果 升级等级       材料名称  需要的数量
# 0             0  古代勇者之魂    无   一星  白银波克布林的犄角      9
# 1             1  古代勇者之魂    无   一星    西诺克斯的肝脏      9
# 2             2  古代勇者之魂    无   一星      左纳尼乌姆     15
# 3             3  古代勇者之魂    无   二星  白银莫力布林的犄角      9
# 4             4  古代勇者之魂    无   二星    巨霸迦马的肝脏      9
# ..          ...     ...  ...  ...        ...    ...
# 205         205    橡胶套装  雷无效   三星  电麻蜥蜴战士的尾巴      5
# 206         206    橡胶套装  雷无效   三星       酥麻香草      8
# 207         207    橡胶套装  雷无效   四星  电麻蜥蜴战士的犄角      5
# 208         208    橡胶套装  雷无效   四星         黄玉      5
# 209         209    橡胶套装  雷无效   四星  电麻蜥蜴战士的尾巴      8
#
# [210 rows x 6 columns]

# %%
equip_name = "古代勇者之魂"
level = "一星"


selected_equipment = equipment_data[
    (equipment_data["名称"]==equip_name) & (equipment_data["升级等级"] == level)]
selected_equipment
# Out:
#    Unnamed: 0      名称 套装效果 升级等级       材料名称  需要的数量
# 0           0  古代勇者之魂    无   一星  白银波克布林的犄角      9
# 1           1  古代勇者之魂    无   一星    西诺克斯的肝脏      9
# 2           2  古代勇者之魂    无   一星      左纳尼乌姆     15

# %%
selected_materials = pd.DataFrame(columns=['材料名称', '需要的数量'])
for _, row in selected_equipment.iterrows():
    material = row['材料名称']
    quantity = row['需要的数量']
    selected_materials = selected_materials.append({'材料名称': material, '需要的数量': quantity},
                                                       ignore_index=True)
selected_materials
# Out:
# /var/folders/mc/xky969md5ld_1jd18hqgv6_m0000gq/T/com.apple.shortcuts.mac-helper/ipykernel_6779/3111946252.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_materials = selected_materials.append({'材料名称': material, '需要的数量': quantity},
# /var/folders/mc/xky969md5ld_1jd18hqgv6_m0000gq/T/com.apple.shortcuts.mac-helper/ipykernel_6779/3111946252.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_materials = selected_materials.append({'材料名称': material, '需要的数量': quantity},
# /var/folders/mc/xky969md5ld_1jd18hqgv6_m0000gq/T/com.apple.shortcuts.mac-helper/ipykernel_6779/3111946252.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_materials = selected_materials.append({'材料名称': material, '需要的数量': quantity},
#         材料名称 需要的数量
# 0  白银波克布林的犄角     9
# 1    西诺克斯的肝脏     9
# 2      左纳尼乌姆    15

# %%
import tkinter as tk
from tkinter import ttk

# 装备数据（示例）
equipments = ['装备1', '装备2', '装备3', '装备4', '装备5']

# 创建空的装备列表
selected_equipments = []

# 添加装备到列表
def add_equipment():
    selected_equipment = equipment_combobox.get()
    if selected_equipment not in selected_equipments:
        selected_equipments.append(selected_equipment)
        selected_listbox.insert(tk.END, selected_equipment)

# 计算所需的材料总数
def calculate_materials():
    # 在这里进行计算所需材料的逻辑
    total_materials = len(selected_equipments)
    print("所需的材料总数：", total_materials)

# 创建窗口
window = tk.Tk()

# 创建下拉列表框
equipment_combobox = ttk.Combobox(window, values=equipments)
equipment_combobox.pack()

# 创建添加按钮
add_button = ttk.Button(window, text="添加", command=add_equipment)
add_button.pack()

# 创建选择列表框
selected_listbox = tk.Listbox(window)
selected_listbox.pack()

# 创建计算按钮
calculate_button = ttk.Button(window, text="计算", command=calculate_materials)
calculate_button.pack()

window.mainloop()
# Out:
# 所需的材料总数： 3

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd
import datetime



# 创建空的装备列表
selected_equipments = []

def clear_selected_listbox():
    global selected_equipments
#     public selected_equipments
    selected_equipments = []
    result_text.delete(1.0, tk.END)
    selected_listbox.delete(0, tk.END)  # 删除所有选项

# 添加装备到列表
def add_equipment():
    global selected_equipments
    (equip, level) = (combo_equipment.get(), combo_level.get())
    if (equip, level) not in selected_equipments:
        selected_equipments.append((equip, level))
        selected_listbox.insert(tk.END, (equip, level))

def calculate_materials():    
    global selected_equipments, total_materials
    # 构建筛选条件
    conditions = pd.Series(False, index=equipment_data.index)
    for (equip, level) in selected_equipments:
        conditions = conditions | ((equipment_data['名称'] == equip) & (equipment_data['升级等级'] == level))
    selected_equipment = equipment_data[conditions]

#     selected_materials = pd.DataFrame(columns=['材料名称', '需要的数量'])
    selected_materials = selected_equipment.iloc[:,-2:]
    
    total_materials = selected_materials.groupby('材料名称')['需要的数量'].sum().reset_index()

    result_text.delete(1.0, tk.END)
    result_text.insert(tk.END, total_materials.to_string(index=False))

def save_instructions():
    global total_materials
    ts = datetime.datetime.now().timestamp()

    ts = datetime.datetime.now().timestamp()
    total_materials.to_csv(f"saved_materials_{str(ts).split('.')[1]}.csv") 
    print("材料表已保存到csv文件")

equipment_data = pd.read_csv('Documents/material_output_2.csv')

# 创建主窗口
window = tk.Tk()
window.title("装备材料计算器")

# 创建下拉选择框和标签
label_equipment = ttk.Label(window, text="装备名称:")
label_equipment.pack()
combo_equipment = ttk.Combobox(window, values=equipment_data['名称'].unique().tolist())
combo_equipment.pack()

label_level = ttk.Label(window, text="装备等级:")
label_level.pack()
combo_level = ttk.Combobox(window, values=equipment_data['升级等级'].unique().tolist())
combo_level.pack()

# 创建添加按钮
add_button = ttk.Button(window, text="添加", command=add_equipment)
add_button.pack()

# 创建选择列表框
selected_listbox = tk.Listbox(window)
selected_listbox.pack()

# 创建清空选项的按钮
clear_button = tk.Button(window, text='清空选项', command=clear_selected_listbox)
clear_button.pack()

# 创建计算按钮
calculate_button = ttk.Button(window, text="计算", command=calculate_materials)
calculate_button.pack()

# 创建结果文本框
result_text = tk.Text(window, height=10, width=30)
result_text.pack()

# 创建保存按钮
save_button = tk.Button(window, text="保存到csv", command=save_instructions)
save_button.pack()

# 启动主循环
window.mainloop()
# Out:
# 指令已保存到 saved_materials.csv 文件
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 107
#     104 save_button.pack()
#     106 # 启动主循环
# --> 107 window.mainloop()
#
# File ~/anaconda3/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import datetime

ts = datetime.datetime.now().timestamp()
str(ts).split('.')[1]
# Out:
# '173531'

# %%
# 构建筛选条件

equip_name = "古代勇者之魂"
level = "一星"
conditions = pd.Series(False, index=equipment_data.index)
conditions = conditions | ((equipment_data['名称'] == equip_name) & (equipment_data['升级等级'] == level))
    
selected_equipment = equipment_data[conditions]


selected_equipment.iloc[:,-2:]
# Out:
#         材料名称  需要的数量
# 0  白银波克布林的犄角      9
# 1    西诺克斯的肝脏      9
# 2      左纳尼乌姆     15
